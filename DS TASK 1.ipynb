# %% [markdown]
# # TASK 1

# %% [markdown]
# # OASIS INFOBYTE INTERNSHIP
# Name  : Gourang N. Lawane

# %% [markdown]
# Batch : September-P2 Batch Oasis Infobyte SIP

# %% [markdown]
# # Sales Prediction Using Python
# -Data science internship

# %% [markdown]
# # import all packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # read file / Dataset

# %%
data_set=pd.read_csv("C:\\Users\\91937\\Desktop\\oasis intern CSV\\Advertising.csv")

# %%
data_set
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # No of Columns in Dataset

# %%
data_set.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# # No of Index in Dataset

# %%
data_set.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %% [markdown]
# # Shape of Dataset

# %%
data_set.shape
# Out:
# (200, 5)

# %% [markdown]
# # Size of Dataset

# %%
data_set.size
# Out:
# 1000

# %% [markdown]
# # Head 5 Data

# %%
data_set.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# # Last 5 Data

# %%
data_set.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# # INFORMATION

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# # DESCRIBE

# %%
data_set.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data_set.describe().sum()
# Out:
# Unnamed: 0     860.879185
# TV            1172.946736
# Radio          357.110809
# Newspaper      450.232621
# Sales          288.514957
# dtype: float64

# %%
x=data_set.iloc[:,-1]
x
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# # Null value

# %%
data_set.isnull()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %% [markdown]
# # sum of null value

# %%
data_set.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# # Duplicated value

# %%
data_set.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %% [markdown]
# # Histogram for TV

# %%
sns.histplot(data_set['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Count'>

# %% [markdown]
# # Boxplot

# %%
plt.figure(figsize=[5,3])
plt.boxplot(data_set,vert=False,data=data_set.columns)
plt.show()

# %% [markdown]
# # Histogram for Newspaper

# %%
sns.histplot(data_set['Newspaper'])
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Count'>

# %% [markdown]
# # Histogram for Radio

# %%
sns.histplot(data_set['Radio'])
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Count'>

# %% [markdown]
# # Histogram for Sales

# %%
sns.histplot(data_set['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Count'>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(data_set)

# %% [markdown]
# # Heatmap graph

# %%
sns.heatmap(data_set.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # sales feature distribution

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.histplot(data_set['Sales'],color='maroon',kde=True)
plt.title('Sales feature Distribution',fontweight="black",pad=20,fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales feature Distribution')

# %%
data_set.hist(bins=50)
plt.show()

# %% [markdown]
# # check the correlation of features.

# %%
plt.figure(figsize=(20,6))
sns.heatmap(data_set.corr(),annot=True,cmap="summer")
plt.title("coorelation among the Fetaures",fontweight = 'black',fontsize = 22 , pad=20)
plt.show()
